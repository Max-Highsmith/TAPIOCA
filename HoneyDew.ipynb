# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
Image(filename='Images/honeydew.png')

# %% [markdown]
# # HoneyDew
# Here we present Honeydew, a network for predicting genomic structural features using epigenetic data.  In keeping with the naming convention of "muppet networks" honeydew is a tool which incorporates self-attention mechanisms to effectively predict higher order genomic conformational structures such as AB compartments and TADs.

# %% [markdown]
# Data Assembly:
# First we gather some data for our experimetns.  We first pull epigenetic data from Roswnwald et al "A machine learning framework for the prediction of chromatin folding in drosophila using epigenetic features" https://peerj.com/articles/cs-307/
#
# This data contains a collection of 18 epigentic track features along three different cell lines and corresponding amaratus gamma

# %%
# !mkdir Data
# !mkdir Data/Drosophilla
# !wget -P Data/Drosophilla https://github.com/MichalRozenwald/Hi-ChIP-ML/blob/master/data/epigenetics/s2_kc_bg_scaled_18_features_2901.csv
# !wget -P Data/Drosophilla https://github.com/MichalRozenwald/Hi-ChIP-ML/blob/master/data/target/s2_kc_bg_clean_gamma_2901.csv
# Out:
# --2021-02-10 13:03:37--  https://github.com/MichalRozenwald/Hi-ChIP-ML/blob/master/data/epigenetics/s2_kc_bg_scaled_18_features_2901.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Data/Drosophilla/s2_kc_bg_scaled_18_features_2901.csv’
#
# s2_kc_bg_scaled_18_     [ <=>                ]  87.08K  --.-KB/s    in 0.08s
#
# 2021-02-10 13:03:38 (1.11 MB/s) - ‘Data/Drosophilla/s2_kc_bg_scaled_18_features_2901.csv’ saved [89169]
#
# --2021-02-10 13:03:38--  https://github.com/MichalRozenwald/Hi-ChIP-ML/blob/master/data/target/s2_kc_bg_clean_gamma_2901.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Data/Drosophilla/s2_kc_bg_clean_gamma_2901.csv’
#
# s2_kc_bg_clean_gamm     [   <=>              ]   3.75M  8.24MB/s    in 0.5s
#
# 2021-02-10 13:03:39 (8.24 MB/s) - ‘Data/Drosophilla/s2_kc_bg_clean_gamma_2901.csv’ saved [3932139]

# %% [markdown]
# We can visualize this data briefly using pandas
